# %% [markdown]
# # Asymptotic Notation

# %% [markdown]
# 1. f(n) =  n-10, g(n) = n+10, can we write it in Theta(n)

# %% [markdown]
# ![Question1.jpeg](attachment:Question1.jpeg)

# %% [markdown]
# 2. f(n) = n ,g(n) = n, f(n) = theta(g(n)) ?

# %% [markdown]
# ![Question2.jpeg](attachment:Question2.jpeg)

# %% [markdown]
# 3. 64 ^ log2 n. 32 ^ log2 n = O(n^5) ? is it correct

# %% [markdown]
# ![Question3.jpeg](attachment:Question3.jpeg)

# %% [markdown]
# 4. 4^n / 2^n = O(2^n).. is it correct?

# %% [markdown]
# ![Question4.jpeg](attachment:Question4.jpeg)

# %% [markdown]
# 5. 128 ^ log2 n . n^2 = Theta(n^9).. is it correct>

# %% [markdown]
# ![Question5.jpeg](attachment:Question5.jpeg)
