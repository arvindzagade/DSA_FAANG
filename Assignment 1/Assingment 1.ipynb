# %% [markdown]
# ### Apriori Analysis

# %% [markdown]
# ### 1

# %% [raw]
# i = n
# while i>2:
#     i = i ^ 1/25
#     print(i)

# %% [markdown]
# <img ![problem1.jpeg](attachment:problem1.jpeg)

# %% [markdown]
# #### 2

# %% [raw]
# i = 29
#  while i <n:
#         i = i^23

# %% [markdown]
# ![problem2.jpeg](attachment:problem2.jpeg)

# %% [markdown]
# #### 3

# %% [raw]
# i = 1
# while i < n:
#     i = i * 2
#     i = i*3

# %% [markdown]
# ![problem3.jpeg](attachment:problem3.jpeg)

# %% [markdown]
# ![problem_3.jpeg](attachment:problem_3.jpeg)
