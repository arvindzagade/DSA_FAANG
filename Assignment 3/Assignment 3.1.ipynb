# %% [markdown]
# ### Recursion Problems

# %% [raw]
#  T(n) = {1, n=1
#
#         2T(n/2) + n, n>1}

# %% [markdown]
# ![Question1.jpeg](attachment:Question1.jpeg)

# %% [raw]
#  T(n) = {1, n=1
#
#         8T(n/2) + n^2, n>1}

# %% [markdown]
# ![Question3.jpeg](attachment:Question3.jpeg)
